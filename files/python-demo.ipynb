# %% [markdown]
# # jmshea's JupyterLite Python Demo

# %% [markdown]
# Demonstate using NumPy functions and Matplotlib plotting:

# %%
from numpy import linspace, sin, pi
from matplotlib.pyplot import plot
# %matplotlib inline

# %%
t = linspace(0, 1, 100)
y = sin(2 * pi * t) 

plot(t, y);
